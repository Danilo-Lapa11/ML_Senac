# %% [markdown]
# #### Assunto do Laboratório 3:
# - Comando de iteração

# %% [markdown]
# ### Questão 1:
#
# Crie um programa que imprima todos os números pares de 0 a 100.

# %%
loop = True
cont = 0
while loop == True:
  if cont % 2 == 0:
    print(cont)
  if not cont < 100:
    loop = False
  cont += 1

# %% [markdown]
# ### Questão 2:
#
# Desenvolver um algoritmo que efetue a soma de todos os números ímpares que são múltiplos de três e que se encontram no conjunto dos números de 1 até 500.

# %%
soma = 0
numero = 1

while numero <= 500:
    if numero % 2 != 0 and numero % 3 == 0:
        soma += numero
    numero += 1

print("A soma dos números ímpares múltiplos de três de 1 até 500 é:", soma)
# Out:
# A soma dos números ímpares múltiplos de três de 1 até 500 é: 20667

# %% [markdown]
# ### Questão 3:
#
# Desenvolver um algoritmo que leia a altura de 15 pessoas. Este programa deverá calcular e mostrar :
#
# a. A menor altura do grupo;
#
# b. A maior altura do grupo;

# %%
cont = 0
menor = 0
maior = 0

while cont < 5 :

  if cont == 0 :
    altura = float(input())
    menor = altura
    maior = altura


  elif cont > 0:
    altura = float(input())
    if altura > maior :
      maior = altura
    elif altura < menor:
      menor = altura

  cont += 1

print(menor, maior)
# Out:
# 1.8
# 1.4
# 2.0
# 1.67
# 1.88
# 1.4 2.0

# %% [markdown]
# ### Questão 4:
#
# Construa um programa que lê um número inteiro N a partir do teclado e calcula a raiz quinta inteira desse número, se houver. Caso não haja, ele deve informar isso ao usuário.

# %%
num = int(input("digite o num inteiro: "))

raiz = num ** (1/5)

if type(raiz) == int :
  print("eh raiz inteira")
else:
  print("NAO eh raiz inteira")
raiz
# Out:
# digite o num inteiro: 25
# NAO eh raiz inteira
# 1.9036539387158786

# %% [markdown]
# ### Questão 5:
#
# Escrever um algoritmo que leia uma quantidade desconhecida de números e conte quantos deles estão nos seguintes intervalos: [0-25], [26-50], [51-75] e [76-100]. A entrada de dados deve terminar quando for lido um número negativo.

# %%
'''
[0-25] = A
[26-50] = B
[51-75] = C
[76-100] = D
'''
intervalo_A = 0
intervalo_B = 0
intervalo_C = 0
intervalo_D = 0

loop = True
while loop == True:
  num = int(input())
  if num < 0 :
    loop = False
  if (25 >= num >= 0):
    intervalo_A += 1
  elif (26 <= num <=50):
    intervalo_B += 1
  elif (51 <= num <=75):
    intervalo_C += 1
  elif (76 <= num <=100):
    intervalo_D += 1

print(f"A = {intervalo_A}, B = {intervalo_B}, C = {intervalo_C}, D = {intervalo_D}")
# Out:
# 0
# 25
# 50
# 75
# 100
# -1
# A = 2, B = 1, C = 1, D = 1

# %% [markdown]
# ### Questão 6:
#
# Faça um algoritmo estruturado que leia uma quantidade não determinada de números positivos. Calcule a quantidade de números pares e ímpares, a média de valores pares e a média geral dos números lidos. O número que encerrará a leitura será zero.

# %%
total_numeros = 0
soma_numeros = 0
total_pares = 0
soma_pares = 0


while True:
    numero = int(input("Digite um número (ou 0 para encerrar): "))

    if numero == 0:
        break

    total_numeros += 1
    soma_numeros += numero

    if numero % 2 == 0:
        total_pares += 1
        soma_pares += numero

media_geral = soma_numeros / total_numeros if total_numeros > 0 else 0

media_pares = soma_pares / total_pares if total_pares > 0 else 0

print("Quantidade de números pares:", total_pares)
print("Quantidade de números ímpares:", total_numeros - total_pares)
print("Média dos valores pares:", media_pares)
print("Média geral dos números lidos:", media_geral)
# Out:
# Digite um número (ou 0 para encerrar): 20
# Digite um número (ou 0 para encerrar): 20
# Digite um número (ou 0 para encerrar): 0
# Quantidade de números pares: 2
# Quantidade de números ímpares: 0
# Média dos valores pares: 20.0
# Média geral dos números lidos: 20.0
